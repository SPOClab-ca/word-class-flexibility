# %% [markdown]
# # WALS Correlation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
values_df = pd.read_csv('../data/wals-2020/cldf/values.csv')
parameters_df = pd.read_csv('../data/wals-2020/cldf/parameters.csv')
codes_df = pd.read_csv('../data/wals-2020/cldf/codes.csv')
language_names_df = pd.read_csv('../data/wals-2020/cldf/language_names.csv')

# %% [markdown]
# ## Denormalize values table

# %%
language_names_df = language_names_df.groupby('Language_ID').first()
df = pd.merge(values_df, language_names_df, on='Language_ID')
df = df[['Language_ID', 'Name', 'Parameter_ID', 'Value']].rename(columns={'Name': 'Language_Name', 'Value': 'Parameter_Value'})
df = pd.merge(df, parameters_df, left_on='Parameter_ID', right_on='ID')
df = df[['Language_ID', 'Language_Name', 'Parameter_ID', 'Name', 'Area', 'Parameter_Value']].rename(columns={'Name': 'Parameter_Name'})
df = pd.merge(df, codes_df, left_on=('Parameter_ID', 'Parameter_Value'), right_on=('Parameter_ID', 'Number'))
df = df[['Language_ID', 'Language_Name', 'Area', 'Parameter_Name', 'Name', 'Description']].rename(columns={'Name': 'Value'})
df
# Out:
#       Language_ID          Language_Name        Area  \
# 0             aar                   Aari  Morphology
# 1             abi                 Abipon  Morphology
# 2             abn                Arabana  Morphology
# 3             acu         Achuar-Shiwiar  Morphology
# 4             adn          Adnyamathanha  Morphology
# ...           ...                    ...         ...
# 74109         hna                   Mina  Word Order
# 74110         ygr  Yagaria, Move dialect  Word Order
# 74111         jms          Dogon, Jamsay  Word Order
# 74112         kmb                 Kombai  Word Order
# 74113         kob                  Kobon  Word Order
#
#                                           Parameter_Name  \
# 0      Prefixing vs. Suffixing in Inflectional Morpho...
# 1      Prefixing vs. Suffixing in Inflectional Morpho...
# 2      Prefixing vs. Suffixing in Inflectional Morpho...
# 3      Prefixing vs. Suffixing in Inflectional Morpho...
# 4      Prefixing vs. Suffixing in Inflectional Morpho...
# ...                                                  ...
# 74109                     Double-headed relative clauses
# 74110                     Double-headed relative clauses
# 74111                     Double-headed relative clauses
# 74112                     Double-headed relative clauses
# 74113                     Double-headed relative clauses
#
#                                     Value                         Description
# 0                      Strongly suffixing             Predominantly suffixing
# 1                      Strongly suffixing             Predominantly suffixing
# 2                      Strongly suffixing             Predominantly suffixing
# 3                      Strongly suffixing             Predominantly suffixing
# 4                      Strongly suffixing             Predominantly suffixing
# ...                                   ...                                 ...
# 74109   Double-headed as nondominant type   Double-headed as nondominant type
# 74110   Double-headed as nondominant type   Double-headed as nondominant type
# 74111  Double-headed or internally-headed  Double-headed or internally-headed
# 74112              Double-headed dominant              Double-headed dominant
# 74113               Double-headed or RelN               Double-headed or RelN
#
# [74114 rows x 6 columns]

# %% [markdown]
# ## Compare two languages on differences

# %%
lang1_df = df[df.Language_ID == 'slo']
lang2_df = df[df.Language_ID == 'pol']
both_df = pd.merge(lang1_df, lang2_df, on='Parameter_Name')
both_df = both_df[['Area_x', 'Parameter_Name', 'Value_x', 'Value_y']]
both_df = both_df.rename(columns={'Value_x': 'Lang1', 'Value_y': 'Lang2'})
both_df[both_df.Lang1 != both_df.Lang2]
# Out:
#                Area_x                                     Parameter_Name  \
# 3          Word Order                          Order of Subject and Verb
# 6          Word Order                         Order of Genitive and Noun
# 12     Simple Clauses                  Expression of Pronominal Subjects
# 27          Phonology                             Fixed Stress Locations
# 28          Phonology                            Weight-Sensitive Stress
# 29          Phonology  Weight Factors in Weight-Sensitive Stress Systems
# 33  Verbal Categories                              Epistemic Possibility
# 38            Lexicon                                                Tea
# 41          Phonology                                       Rhythm Types
#
#                                 Lang1                                 Lang2
# 3                                  SV                     No dominant order
# 6                   No dominant order                         Noun-Genitive
# 12            Subject affixes on verb      Subject clitics on variable host
# 27                    No fixed stress                           Penultimate
# 28  Unbounded: Stress can be anywhere  Fixed stress (no weight-sensitivity)
# 29                         Prominence                             No weight
# 33                              Other                  Verbal constructions
# 38     Words derived from Sinitic cha                                Others
# 41                 No rhythmic stress                              Trochaic
